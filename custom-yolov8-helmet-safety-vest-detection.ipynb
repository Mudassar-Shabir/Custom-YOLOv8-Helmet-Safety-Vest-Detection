# %%
import os

for root, dirs, files in os.walk("/kaggle/input"):
    print(root)

# %%
import os

dataset_path = "/kaggle/input/datasets/muhammetzahitaydn/hardhat-vest-dataset-v3"

print(os.listdir(dataset_path))

# %%
# %%writefile /kaggle/working/data.yaml
#
# train: /kaggle/input/datasets/muhammetzahitaydn/hardhat-vest-dataset-v3/images/train
# val: /kaggle/input/datasets/muhammetzahitaydn/hardhat-vest-dataset-v3/images/val
# test: /kaggle/input/datasets/muhammetzahitaydn/hardhat-vest-dataset-v3/images/test
#
# nc: 4
#
# names:
#   0: helmet
#   1: vest
#   2: head
#   3: person

# %%
with open("/kaggle/working/data.yaml","r") as f:
    print(f.read())

# %%
# !pip install -q ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.train(
    data="/kaggle/working/data.yaml",
    epochs=10,
    imgsz=640,
    batch=10
)

# %%
# !find /kaggle/working -name "best.pt"

# %%
# !ls /kaggle/working

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/working/custom_yolo_best.pt")

results = model.predict(
    source="/kaggle/input/datasets/muhammetzahitaydn/hardhat-vest-dataset-v3/images/test",
    conf=0.25,
    save=True
)

# %%
from IPython.display import Image, display
import glob

prediction = glob.glob("/kaggle/working/runs/detect/predict/*.jpg")[2]
display(Image(filename=prediction))
